# %%
print("1. Name - название пива в краткой или распространённой форме.")
print("2. Style - Категория или стиль пива (например, IPA, Stout, Lager и т.д.).")
print("3. Brewery - Название пивоварни, которая изготовила пиво.")
print("4. Beer Name (Full) - Полное, официальное название пива.")
print("5. Description - Текстовое описание пива, содержащее информацию о вкусовых характеристиках, аромате и особенностях.")
print("6. ABV - Alcohol By Volume, то есть процентное содержание алкоголя в пиве.")
print("7. Min IBU - Минимальное значение горечи, измеряемое в International Bitterness Units")
print("8. Max IBU - Максимальное значение горечи в IBU.")
print("\n9. Astringency - Оценка вяжущего эффекта или сухости пива, ощущаемой во рту.")
print("10. Body - Ощущение полноты или 'тела' пива – насколько напиток воспринимается насыщенным или легким.")
print("11. Alcohol - Субъективная оценка ощущаемой алкогольности, которая может отличаться от механически измеренного ABV.")
print("12. Bitter - Оценка горечи пива по вкусу.")
print("13. Sweet - Оценка сладости пива.")
print("14. Sour - Оценка кислинки во вкусе пива.")
print("15. Salty - Оценка солёности пива.")
print("16. Fruits - Оценка фруктовых нот, которые могут присутствовать в аромате или вкусе пива.")
print("17. Hoppy - Оценка выраженности хмелевых нот – характерного для некоторых стилей пива вкусового акцента.")
print("18. Spices - Оценка наличия пряных нот в пиве.")
print("19. Malty - Оценка выраженности солодовых (мальтовых) нот.")
print("\n20. review_aroma - Средняя оценка аромата пива по отзывам дегустаторов.")
print("21. review_appearance - Средняя оценка внешнего вида пива (цвет, прозрачность, пенка и т.д.) по отзывам.")
print("22. review_palate - Средняя оценка ощущений пива во рту (текстура, баланс вкуса) по отзывам.")
print("23. review_taste - Средняя оценка вкуса пива, суммирующая все вкусовые ощущения.")
print("24. review_overall - Общая итоговая оценка пива по результатам отзывов дегустаторов.")
print("25. number_of_reviews - Количество отзывов, на основе которых были выставлены оценки.")
# Out:
# 1. Name - название пива в краткой или распространённой форме.
# 2. Style - Категория или стиль пива (например, IPA, Stout, Lager и т.д.).
# 3. Brewery - Название пивоварни, которая изготовила пиво.
# 4. Beer Name (Full) - Полное, официальное название пива.
# 5. Description - Текстовое описание пива, содержащее информацию о вкусовых характеристиках, аромате и особенностях.
# 6. ABV - Alcohol By Volume, то есть процентное содержание алкоголя в пиве.
# 7. Min IBU - Минимальное значение горечи, измеряемое в International Bitterness Units
# 8. Max IBU - Максимальное значение горечи в IBU.
#
# 9. Astringency - Оценка вяжущего эффекта или сухости пива, ощущаемой во рту.
# 10. Body - Ощущение полноты или 'тела' пива – насколько напиток воспринимается насыщенным или легким.
# 11. Alcohol - Субъективная оценка ощущаемой алкогольности, которая может отличаться от механически измеренного ABV.
# 12. Bitter - Оценка горечи пива по вкусу.
# 13. Sweet - Оценка сладости пива.
# 14. Sour - Оценка кислинки во вкусе пива.
# 15. Salty - Оценка солёности пива.
# 16. Fruits - Оценка фруктовых нот, которые могут присутствовать в аромате или вкусе пива.
# 17. Hoppy - Оценка выраженности хмелевых нот – характерного для некоторых стилей пива вкусового акцента.
# 18. Spices - Оценка наличия пряных нот в пиве.
# 19. Malty - Оценка выраженности солодовых (мальтовых) нот.
#
# 20. review_aroma - Средняя оценка аромата пива по отзывам дегустаторов.
# 21. review_appearance - Средняя оценка внешнего вида пива (цвет, прозрачность, пенка и т.д.) по отзывам.
# 22. review_palate - Средняя оценка ощущений пива во рту (текстура, баланс вкуса) по отзывам.
# 23. review_taste - Средняя оценка вкуса пива, суммирующая все вкусовые ощущения.
# 24. review_overall - Общая итоговая оценка пива по результатам отзывов дегустаторов.
# 25. number_of_reviews - Количество отзывов, на основе которых были выставлены оценки.

# %%
import pandas as pd

# Загрузка данных из CSV-файла
df = pd.read_csv('./data/beer_profile_and_ratings.csv')

print(df.head())
# Out:
#                            Name    Style  \
# 0                         Amber  Altbier
# 1                    Double Bag  Altbier
# 2                Long Trail Ale  Altbier
# 3                  Doppelsticke  Altbier
# 4  Sleigh'r Dark Doüble Alt Ale  Altbier
#
#                                             Brewery  \
# 0                               Alaskan Brewing Co.
# 1                            Long Trail Brewing Co.
# 2                            Long Trail Brewing Co.
# 3  Uerige Obergärige Hausbrauerei GmbH / Zum Uerige
# 4                           Ninkasi Brewing Company
#
#                                     Beer Name (Full)  \
# 0                  Alaskan Brewing Co. Alaskan Amber
# 1                  Long Trail Brewing Co. Double Bag
# 2              Long Trail Brewing Co. Long Trail Ale
# 3  Uerige Obergärige Hausbrauerei GmbH / Zum Ueri...
# 4  Ninkasi Brewing Company Sleigh'r Dark Doüble A...
#
#                                          Description  ABV  Min IBU  Max IBU  \
# 0  Notes:Richly malty and long on the palate, wit...  5.3       25       50
# 1  Notes:This malty, full-bodied double alt is al...  7.2       25       50
# 2  Notes:Long Trail Ale is a full-bodied amber al...  5.0       25       50
# 3                                             Notes:  8.5       25       50
# 4  Notes:Called 'Dark Double Alt' on the label.Se...  7.2       25       50
#
#    Astringency  Body  ...  Fruits  Hoppy  Spices  Malty  review_aroma  \
# 0           13    32  ...      33     57       8    111      3.498994
# 1           12    57  ...      24     35      12     84      3.798337
# 2           14    37  ...      10     54       4     62      3.409814
# 3           13    55  ...      49     40      16    119      4.148098
# 4           25    51  ...      11     51      20     95      3.625000
#
#    review_appearance  review_palate  review_taste  review_overall  \
# 0           3.636821       3.556338      3.643863        3.847082
# 1           3.846154       3.904366      4.024948        4.034304
# 2           3.667109       3.600796      3.631300        3.830239
# 3           4.033967       4.150815      4.205163        4.005435
# 4           3.973958       3.734375      3.765625        3.817708
#
#    number_of_reviews
# 0                497
# 1                481
# 2                377
# 3                368
# 4                 96
#
# [5 rows x 25 columns]

# %%
print("Data type: ", type(df))
print("Data shape: ", df.shape)
print(df.dtypes)
# Out:
# Data type:  <class 'pandas.core.frame.DataFrame'>
# Data shape:  (3197, 25)
# Name                  object
# Style                 object
# Brewery               object
# Beer Name (Full)      object
# Description           object
# ABV                  float64
# Min IBU                int64
# Max IBU                int64
# Astringency            int64
# Body                   int64
# Alcohol                int64
# Bitter                 int64
# Sweet                  int64
# Sour                   int64
# Salty                  int64
# Fruits                 int64
# Hoppy                  int64
# Spices                 int64
# Malty                  int64
# review_aroma         float64
# review_appearance    float64
# review_palate        float64
# review_taste         float64
# review_overall       float64
# number_of_reviews      int64
# dtype: object

# %%
print("\nКоличество пропущенных значений в каждом столбце:")
print(df.isnull().sum())
# Out:
# Количество пропущенных значений в каждом столбце:
# Name                 0
# Style                0
# Brewery              0
# Beer Name (Full)     0
# Description          0
# ABV                  0
# Min IBU              0
# Max IBU              0
# Astringency          0
# Body                 0
# Alcohol              0
# Bitter               0
# Sweet                0
# Sour                 0
# Salty                0
# Fruits               0
# Hoppy                0
# Spices               0
# Malty                0
# review_aroma         0
# review_appearance    0
# review_palate        0
# review_taste         0
# review_overall       0
# number_of_reviews    0
# dtype: int64

# %%
print("\nОсновные статистические показатели числовых признаков:")
print(df.describe())
# Out:
# Основные статистические показатели числовых признаков:
#                ABV      Min IBU      Max IBU  Astringency         Body  \
# count  3197.000000  3197.000000  3197.000000  3197.000000  3197.000000
# mean      6.526688    21.180482    38.986863    16.515796    46.129496
# std       2.546997    13.242242    21.355281    10.410661    25.947842
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000    15.000000    25.000000     9.000000    29.000000
# 50%       6.000000    20.000000    35.000000    14.000000    40.000000
# 75%       7.600000    25.000000    45.000000    21.000000    58.000000
# max      57.500000    65.000000   100.000000    81.000000   175.000000
#
#            Alcohol       Bitter        Sweet         Sour        Salty  \
# count  3197.000000  3197.000000  3197.000000  3197.000000  3197.000000
# mean     17.055990    36.364404    58.270879    33.145449     1.017204
# std      17.331334    25.791152    34.281310    35.780172     2.132651
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       6.000000    17.000000    33.000000    11.000000     0.000000
# 50%      11.000000    31.000000    54.000000    22.000000     0.000000
# 75%      22.000000    52.000000    77.000000    42.000000     1.000000
# max     139.000000   150.000000   263.000000   284.000000    48.000000
#
#             Fruits        Hoppy       Spices        Malty  review_aroma  \
# count  3197.000000  3197.000000  3197.000000  3197.000000   3197.000000
# mean     38.529559    40.924617    18.345637    75.330935      3.638789
# std      32.296646    30.403641    23.756582    39.909338      0.503209
# min       0.000000     0.000000     0.000000     0.000000      1.509615
# 25%      12.000000    18.000000     4.000000    45.000000      3.422559
# 50%      29.000000    33.000000    10.000000    73.000000      3.720183
# 75%      60.000000    56.000000    23.000000   103.000000      3.978000
# max     175.000000   172.000000   184.000000   239.000000      5.000000
#
#        review_appearance  review_palate  review_taste  review_overall  \
# count        3197.000000    3197.000000   3197.000000     3197.000000
# mean            3.754393       3.660428      3.702496        3.747522
# std             0.403416       0.449937      0.510361        0.444288
# min             1.571429       1.285714      1.214286        1.136364
# 25%             3.604651       3.470021      3.500000        3.566667
# 50%             3.833333       3.741667      3.791667        3.830239
# 75%             4.000000       3.965587      4.033333        4.032847
# max             4.666667       5.000000      5.000000        5.000000
#
#        number_of_reviews
# count        3197.000000
# mean          233.284955
# std           361.811847
# min             1.000000
# 25%            23.000000
# 50%            93.000000
# 75%           284.000000
# max          3290.000000

# %%
print("\nМедиана для числовых признаков:")
print(df.median(numeric_only=True))
# Out:
# Медиана для числовых признаков:
# ABV                   6.000000
# Min IBU              20.000000
# Max IBU              35.000000
# Astringency          14.000000
# Body                 40.000000
# Alcohol              11.000000
# Bitter               31.000000
# Sweet                54.000000
# Sour                 22.000000
# Salty                 0.000000
# Fruits               29.000000
# Hoppy                33.000000
# Spices               10.000000
# Malty                73.000000
# review_aroma          3.720183
# review_appearance     3.833333
# review_palate         3.741667
# review_taste          3.791667
# review_overall        3.830239
# number_of_reviews    93.000000
# dtype: float64

# %%
# Функция для обрезки значения до символа '-' (не включая его)
def trim_style(style):
    if '-' in style:
        return style.split('-')[0].strip()  # Обрезаем до '-' и убираем пробелы
    return style  # Если '-' нет, возвращаем исходное значение

# Применяем функцию к столбцу 'Style'
df['Style'] = df['Style'].apply(trim_style)

# Получение уникальных значений из столбца 'Style'
unique_styles = df['Style'].unique()

# Вывод уникальных значений
print("Сорта пива (Уникальные значения в столбце без разделения на регионы и тд.)")
for style in unique_styles:
    print(style)
# Out:
# Сорта пива (Уникальные значения в столбце без разделения на регионы и тд.)
# Altbier
# Barleywine
# Bitter
# Bière de Champagne / Bière Brut
# Blonde Ale
# Bock
# Braggot
# Brett Beer
# Brown Ale
# California Common / Steam Beer
# Chile Beer
# Cream Ale
# Dubbel
# Farmhouse Ale
# Fruit and Field Beer
# Gruit / Ancient Herbed Ale
# Happoshu
# Herb and Spice Beer
# IPA
# Kvass
# Kölsch
# Lager
# Lambic
# Low Alcohol Beer
# Mild Ale
# Old Ale
# Pale Ale
# Pilsner
# Porter
# Pumpkin Beer
# Quadrupel (Quad)
# Red Ale
# Rye Beer
# Scotch Ale / Wee Heavy
# Scottish Ale
# Smoked Beer
# Sour
# Stout
# Strong Ale
# Tripel
# Wheat Beer
# Wild Ale
# Winter Warmer

# %%
print("\nУникальные значения и их частота для признака 'Style':")
print(df['Style'].value_counts())
# Out:
# Уникальные значения и их частота для признака 'Style':
# Style
# Lager                              567
# Stout                              254
# Wheat Beer                         206
# Porter                             164
# IPA                                163
# Bock                               155
# Strong Ale                         148
# Lambic                             100
# Pale Ale                            98
# Brown Ale                           94
# Red Ale                             90
# Pilsner                             86
# Bitter                              74
# Farmhouse Ale                       72
# Blonde Ale                          64
# Barleywine                          64
# Sour                                57
# Mild Ale                            47
# Dubbel                              41
# Winter Warmer                       40
# Altbier                             39
# Rye Beer                            37
# Fruit and Field Beer                37
# Tripel                              37
# Scotch Ale / Wee Heavy              35
# Scottish Ale                        34
# Quadrupel (Quad)                    34
# Old Ale                             34
# Kölsch                              32
# Low Alcohol Beer                    32
# Pumpkin Beer                        30
# Smoked Beer                         28
# Chile Beer                          25
# Cream Ale                           24
# Herb and Spice Beer                 24
# Happoshu                            23
# Wild Ale                            23
# Kvass                               21
# California Common / Steam Beer      20
# Gruit / Ancient Herbed Ale          19
# Braggot                             14
# Bière de Champagne / Bière Brut      8
# Brett Beer                           3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 15))

for style in unique_styles:
    style_data = df[df['Style'] == style]
    plt.scatter(style_data['Min IBU'], style_data['Max IBU'], label=style)

# Настройка графика
plt.xlabel('Min IBU')
plt.ylabel('Max IBU')
plt.title('Min IBU vs Max IBU by Beer Style')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.grid(True)
plt.tight_layout()

# Показать график
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12, 6))

# Считаем количество каждого стиля
style_counts = df['Style'].value_counts()

style_counts.plot(kind='bar', color='skyblue')

plt.xlabel('Style')
plt.ylabel('Count')
plt.title('Распределение стилей пива')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Содержание алкоголя по стилям пива (Violin Plot)
plt.figure(figsize=(14, 8))

sns.violinplot(x='Style', y='ABV', hue='Style', data=df, inner='quartile', palette='Set3')

plt.xlabel('Style')
plt.ylabel('ABV (Alcohol by Volume)')
plt.title('Содержание алкоголя по стилям пива')
plt.xticks(rotation=90)
plt.ylim([0, 20]) # Единичные высокие значения мешают визуальному анализу  
plt.tight_layout()

# Горечь пива по стилям (Min IBU и Max IBU)
# Группируем данные по стилям и вычисляем средние значения Min IBU и Max IBU
style_ibu = df.groupby('Style')[['Min IBU', 'Max IBU']].mean().reset_index()

# Сортируем данные по среднему значению Min IBU для удобства
style_ibu = style_ibu.sort_values(by='Min IBU', ascending=False)

plt.figure(figsize=(14, 8))

# Ширина столбцов
bar_width = 0.35

# Позиции для столбцов
positions = range(len(style_ibu))

# Строим столбцы для Min IBU
plt.bar(positions, style_ibu['Min IBU'], width=bar_width, color='skyblue', label='Min IBU')

# Строим столбцы для Max IBU
plt.bar([p + bar_width for p in positions], style_ibu['Max IBU'], width=bar_width, color='lightcoral', label='Max IBU')

# Настройка графика
plt.xlabel('Beer Style')
plt.ylabel('IBU (International Bitterness Units)')
plt.title('Горечь пива по стилям (Min IBU и Max IBU)')
plt.xticks([p + bar_width / 2 for p in positions], style_ibu['Style'], rotation=90)  # Подписи по центру столбцов
plt.legend()
plt.tight_layout()

# Показать график
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

numerical_cols = df.select_dtypes(include=['number']).columns

# Создаем гистограммы для каждого числового столбца
df[numerical_cols].hist(figsize=(15, 15))  # figsize для читаемости
plt.suptitle("Гистограммы распределения числовых признаков", fontsize=16)
plt.tight_layout(rect=[0, 0.03, 1, 0.95]) # adjust layout to make space for suptitle
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Выбираем числовые столбцы
numerical_cols = df.select_dtypes(include=['number']).columns

# Calculate the correlation matrix
correlation_matrix = df[numerical_cols].corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=.5)
plt.title("Матрица корреляции числовых признаков")
plt.show()

# %%
from sklearn.cluster import KMeans

# Выбираем признаки для кластеризации (ABV и Avg IBU)
df['Avg IBU'] = (df['Min IBU'] + df['Max IBU']) / 2
X = df[['ABV', 'Avg IBU']]

# Выполняем кластеризацию с помощью K-Means
n_clusters = 7  # Количество кластеров (можно изменить)
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
df['Cluster'] = kmeans.fit_predict(X)

# Кластеризация пива по содержанию алкоголя и горечи
plt.figure(figsize=(12, 8))

# Строим scatter plot с раскраской по кластерам
sns.scatterplot(x='ABV', y='Avg IBU', hue='Cluster', data=df, palette='viridis', s=100)

# Добавляем центры кластеров
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=200, alpha=0.75, marker='X', label='Cluster Centers')

# Настройка графика
plt.xlabel('ABV (Alcohol by Volume)')
plt.ylabel('Average IBU (International Bitterness Units)')
plt.title('Кластеризация пива по содержанию алкоголя и горечи')
plt.legend(title='Cluster')
plt.grid(True)
plt.tight_layout()

# Показать график
plt.show()
